# %%
# Import the library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df=pd.read_csv("C:\\Users\\Rahul Patwal Rajput\\Downloads\\PropertyPrice_Data.csv")

# %%
# First five rows of data
df.head()
# Out:
#    Id Road_Type Property_Shape House_Type  House_Condition  Construction_Year  \
# 0   1     Paved            Reg       1Fam                5               2003
# 1   2     Paved            Reg       1Fam                8               1976
# 2   3     Paved            IR1       1Fam                5               2001
# 3   4     Paved            IR1       1Fam                5               1915
# 4   5     Paved            IR1       1Fam                5               2000
#
#    Remodel_Year  BsmtFinSF1  Total_Basement_Area Air_Conditioning  ...  \
# 0          2003         706                  856                Y  ...
# 1          1976         978                 1262                Y  ...
# 2          2002         486                  920                Y  ...
# 3          1970         216                  756                Y  ...
# 4          2000         655                 1145                Y  ...
#
#    Kitchen_Quality  Rooms_Above_Grade  Fireplaces  Garage  Garage_Built_Year  \
# 0               Gd                  8           0  Attchd             2003.0
# 1               TA                  6           1  Attchd             1976.0
# 2               Gd                  6           1  Attchd             2001.0
# 3               Gd                  7           1  Detchd             1998.0
# 4               Gd                  9           1  Attchd             2000.0
#
#    Garage_Area Pool_Area  Miscellaneous_Value  Year_Sold Sale_Price
# 0  1085.793744         0                    0       2008     208500
# 1   196.316304         0                    0       2007     181500
# 2   218.068403         0                    0       2008     223500
# 3   696.996439         0                    0       2006     140000
# 4   568.859882         0                    0       2008     250000
#
# [5 rows x 26 columns]

# %%
# copy
fulldf=df.copy()

# %%
# Remove identifier column
fulldf.drop('Id',axis=1,inplace=True)

# %%
fulldf.shape
# Out:
# (1459, 25)

# %%
# Info
fulldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Road_Type                  1459 non-null   object
#  1   Property_Shape             1459 non-null   object
#  2   House_Type                 1459 non-null   object
#  3   House_Condition            1459 non-null   int64
#  4   Construction_Year          1459 non-null   int64
#  5   Remodel_Year               1459 non-null   int64
#  6   BsmtFinSF1                 1459 non-null   int64
#  7   Total_Basement_Area        1459 non-null   int64
#  8   Air_Conditioning           1459 non-null   object
#  9   First_Floor_Area           1459 non-null   int64
#  10  Second_Floor_Area          1459 non-null   int64
#  11  LowQualFinSF               1459 non-null   int64
#  12  Underground_Full_Bathroom  1459 non-null   int64
#  13  Full_Bathroom_Above_Grade  1459 non-null   int64
#  14  Bedroom_Above_Grade        1459 non-null   int64
#  15  Kitchen_Quality            1459 non-null   object
#  16  Rooms_Above_Grade          1459 non-null   int64
#  17  Fireplaces                 1459 non-null   int64
#  18  Garage                     1378 non-null   object
#  19  Garage_Built_Year          1378 non-null   float64
#  20  Garage_Area                1459 non-null   float64
#  21  Pool_Area                  1459 non-null   int64
#  22  Miscellaneous_Value        1459 non-null   int64
#  23  Year_Sold                  1459 non-null   int64
#  24  Sale_Price                 1459 non-null   int64
# dtypes: float64(2), int64(17), object(6)
# memory usage: 285.1+ KB

# %%
# Statistical summary
fulldf.describe()
# Out:
#        House_Condition  Construction_Year  Remodel_Year   BsmtFinSF1  \
# count      1459.000000        1459.000000   1459.000000  1459.000000
# mean          5.575051        1971.272104   1984.879369   443.374914
# std           1.113125          30.212814     20.645927   456.142186
# min           1.000000        1872.000000   1950.000000     0.000000
# 25%           5.000000        1954.000000   1967.000000     0.000000
# 50%           5.000000        1973.000000   1994.000000   383.000000
# 75%           6.000000        2000.000000   2004.000000   712.000000
# max           9.000000        2010.000000   2010.000000  5644.000000
#
#        Total_Basement_Area  First_Floor_Area  Second_Floor_Area  LowQualFinSF  \
# count          1459.000000       1459.000000        1459.000000   1459.000000
# mean           1057.293352       1162.562714         347.230295      5.848526
# std             438.824912        386.712553         436.583480     48.639512
# min               0.000000        334.000000           0.000000      0.000000
# 25%             795.500000        882.000000           0.000000      0.000000
# 50%             991.000000       1086.000000           0.000000      0.000000
# 75%            1298.500000       1391.500000         728.000000      0.000000
# max            6110.000000       4692.000000        2065.000000    572.000000
#
#        Underground_Full_Bathroom  Full_Bathroom_Above_Grade  \
# count                1459.000000                1459.000000
# mean                    0.424949                   1.565456
# std                     0.518870                   0.550906
# min                     0.000000                   0.000000
# 25%                     0.000000                   1.000000
# 50%                     0.000000                   2.000000
# 75%                     1.000000                   2.000000
# max                     3.000000                   3.000000
#
#        Bedroom_Above_Grade  Rooms_Above_Grade   Fireplaces  Garage_Built_Year  \
# count          1459.000000        1459.000000  1459.000000        1378.000000
# mean              2.866347           6.518163     0.613434        1978.515965
# std               0.816050           1.625894     0.644687          24.696004
# min               0.000000           2.000000     0.000000        1900.000000
# 25%               2.000000           5.000000     0.000000        1961.000000
# 50%               3.000000           6.000000     1.000000        1980.000000
# 75%               3.000000           7.000000     1.000000        2002.000000
# max               8.000000          14.000000     3.000000        2010.000000
#
#        Garage_Area    Pool_Area  Miscellaneous_Value    Year_Sold  \
# count  1459.000000  1459.000000          1459.000000  1459.000000
# mean    470.934787     2.760795            43.518849  2007.815627
# std     210.668787    40.191018           496.291826     1.328542
# min    -129.369350     0.000000             0.000000  2006.000000
# 25%     329.290489     0.000000             0.000000  2007.000000
# 50%     471.028116     0.000000             0.000000  2008.000000
# 75%     607.184977     0.000000             0.000000  2009.000000
# max    1147.488093   738.000000         15500.000000  2010.000000
#
#           Sale_Price
# count    1459.000000
# mean   180944.102810
# std     79464.918335
# min     34900.000000
# 25%    129950.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000

# %%
# Statistical summary
# For categorical column as well as continonus columns
fulldf.describe(include='all')
# Out:
#        Road_Type Property_Shape House_Type  House_Condition  \
# count       1459           1459       1459      1459.000000
# unique         2              4          5              NaN
# top        Paved            Reg       1Fam              NaN
# freq        1453            924       1219              NaN
# mean         NaN            NaN        NaN         5.575051
# std          NaN            NaN        NaN         1.113125
# min          NaN            NaN        NaN         1.000000
# 25%          NaN            NaN        NaN         5.000000
# 50%          NaN            NaN        NaN         5.000000
# 75%          NaN            NaN        NaN         6.000000
# max          NaN            NaN        NaN         9.000000
#
#         Construction_Year  Remodel_Year   BsmtFinSF1  Total_Basement_Area  \
# count         1459.000000   1459.000000  1459.000000          1459.000000
# unique                NaN           NaN          NaN                  NaN
# top                   NaN           NaN          NaN                  NaN
# freq                  NaN           NaN          NaN                  NaN
# mean          1971.272104   1984.879369   443.374914          1057.293352
# std             30.212814     20.645927   456.142186           438.824912
# min           1872.000000   1950.000000     0.000000             0.000000
# 25%           1954.000000   1967.000000     0.000000           795.500000
# 50%           1973.000000   1994.000000   383.000000           991.000000
# 75%           2000.000000   2004.000000   712.000000          1298.500000
# max           2010.000000   2010.000000  5644.000000          6110.000000
#
#        Air_Conditioning  First_Floor_Area  ...  Kitchen_Quality  \
# count              1459       1459.000000  ...             1459
# unique                2               NaN  ...                4
# top                   Y               NaN  ...               TA
# freq               1364               NaN  ...              734
# mean                NaN       1162.562714  ...              NaN
# std                 NaN        386.712553  ...              NaN
# min                 NaN        334.000000  ...              NaN
# 25%                 NaN        882.000000  ...              NaN
# 50%                 NaN       1086.000000  ...              NaN
# 75%                 NaN       1391.500000  ...              NaN
# max                 NaN       4692.000000  ...              NaN
#
#         Rooms_Above_Grade   Fireplaces  Garage  Garage_Built_Year  \
# count         1459.000000  1459.000000    1378        1378.000000
# unique                NaN          NaN       7                NaN
# top                   NaN          NaN  Attchd                NaN
# freq                  NaN          NaN     869                NaN
# mean             6.518163     0.613434     NaN        1978.515965
# std              1.625894     0.644687     NaN          24.696004
# min              2.000000     0.000000     NaN        1900.000000
# 25%              5.000000     0.000000     NaN        1961.000000
# 50%              6.000000     1.000000     NaN        1980.000000
# 75%              7.000000     1.000000     NaN        2002.000000
# max             14.000000     3.000000     NaN        2010.000000
#
#         Garage_Area    Pool_Area  Miscellaneous_Value    Year_Sold  \
# count   1459.000000  1459.000000          1459.000000  1459.000000
# unique          NaN          NaN                  NaN          NaN
# top             NaN          NaN                  NaN          NaN
# freq            NaN          NaN                  NaN          NaN
# mean     470.934787     2.760795            43.518849  2007.815627
# std      210.668787    40.191018           496.291826     1.328542
# min     -129.369350     0.000000             0.000000  2006.000000
# 25%      329.290489     0.000000             0.000000  2007.000000
# 50%      471.028116     0.000000             0.000000  2008.000000
# 75%      607.184977     0.000000             0.000000  2009.000000
# max     1147.488093   738.000000         15500.000000  2010.000000
#
#            Sale_Price
# count     1459.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean    180944.102810
# std      79464.918335
# min      34900.000000
# 25%     129950.000000
# 50%     163000.000000
# 75%     214000.000000
# max     755000.000000
#
# [11 rows x 25 columns]

# %%
# Missing values
fulldf.isna().sum()
# Out:
# Road_Type                     0
# Property_Shape                0
# House_Type                    0
# House_Condition               0
# Construction_Year             0
# Remodel_Year                  0
# BsmtFinSF1                    0
# Total_Basement_Area           0
# Air_Conditioning              0
# First_Floor_Area              0
# Second_Floor_Area             0
# LowQualFinSF                  0
# Underground_Full_Bathroom     0
# Full_Bathroom_Above_Grade     0
# Bedroom_Above_Grade           0
# Kitchen_Quality               0
# Rooms_Above_Grade             0
# Fireplaces                    0
# Garage                       81
# Garage_Built_Year            81
# Garage_Area                   0
# Pool_Area                     0
# Miscellaneous_Value           0
# Year_Sold                     0
# Sale_Price                    0
# dtype: int64

# %%
# Garage
fulldf['Garage'].dtypes
# Out:
# dtype('O')

# %%
fulldf['Garage'].value_counts()
# Out:
# Attchd     869
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2TFes        5
# 2Types       1
# Name: Garage, dtype: int64

# %%
 sns.boxplot(y=fulldf['Sale_Price'],x=fulldf['Garage'])
# Out:
# <AxesSubplot:xlabel='Garage', ylabel='Sale_Price'>

# %%
tempmode=fulldf['Garage'].mode()[0]
fulldf['Garage'].fillna(tempmode,inplace=True)

# %%
tempmedian
# Out:
# 1980.0

# %%
# Garage_Built_Year
fulldf['Garage_Built_Year'].dtypes
# Out:
# dtype('float64')

# %%
tempmedian=fulldf['Garage_Built_Year'].median()
fulldf['Garage_Built_Year'].fillna(tempmedian,inplace=True)

# %%
fulldf.columns
# Out:
# Index(['Road_Type', 'Property_Shape', 'House_Type', 'House_Condition',
#        'Construction_Year', 'Remodel_Year', 'BsmtFinSF1',
#        'Total_Basement_Area', 'Air_Conditioning', 'First_Floor_Area',
#        'Second_Floor_Area', 'LowQualFinSF', 'Underground_Full_Bathroom',
#        'Full_Bathroom_Above_Grade', 'Bedroom_Above_Grade', 'Kitchen_Quality',
#        'Rooms_Above_Grade', 'Fireplaces', 'Garage', 'Garage_Built_Year',
#        'Garage_Area', 'Pool_Area', 'Miscellaneous_Value', 'Year_Sold',
#        'Sale_Price'],
#       dtype='object')

# %%
# let us verify
fulldf.isna().sum()
# Out:
# Road_Type                    0
# Property_Shape               0
# House_Type                   0
# House_Condition              0
# Construction_Year            0
# Remodel_Year                 0
# BsmtFinSF1                   0
# Total_Basement_Area          0
# Air_Conditioning             0
# First_Floor_Area             0
# Second_Floor_Area            0
# LowQualFinSF                 0
# Underground_Full_Bathroom    0
# Full_Bathroom_Above_Grade    0
# Bedroom_Above_Grade          0
# Kitchen_Quality              0
# Rooms_Above_Grade            0
# Fireplaces                   0
# Garage                       0
# Garage_Built_Year            0
# Garage_Area                  0
# Pool_Area                    0
# Miscellaneous_Value          0
# Year_Sold                    0
# Sale_Price                   0
# dtype: int64

# %%
# Outliers treatment
contvar=fulldf.columns[fulldf.dtypes!='O']
contvar
# Out:
# Index(['House_Condition', 'Construction_Year', 'Remodel_Year', 'BsmtFinSF1',
#        'Total_Basement_Area', 'First_Floor_Area', 'Second_Floor_Area',
#        'LowQualFinSF', 'Underground_Full_Bathroom',
#        'Full_Bathroom_Above_Grade', 'Bedroom_Above_Grade', 'Rooms_Above_Grade',
#        'Fireplaces', 'Garage_Built_Year', 'Garage_Area', 'Pool_Area',
#        'Miscellaneous_Value', 'Year_Sold', 'Sale_Price'],
#       dtype='object')

# %%
IQR=Q3-Q1# IQR - Inter Quartile Range
UpperBound=Q3+1.5*IQR
LowerBound=Q1-1.5*IQR

# %%
#Q1=np.percentile(fulldf['House_Condition'],25)
Q1=np.quantile(fulldf['House_Condition'],.25)
Q1
# Out:
# 5.0

# %%
print(LowerBound)
print(UpperBound)
# Out:
# 3.5
# 7.5

# %%
Q3=np.quantile(fulldf['House_Condition'],.75)
Q3
# Out:
# 6.0

# %%
for col in contvar:
    print(col)
# Out:
# House_Condition
# Construction_Year
# Remodel_Year
# BsmtFinSF1
# Total_Basement_Area
# First_Floor_Area
# Second_Floor_Area
# LowQualFinSF
# Underground_Full_Bathroom
# Full_Bathroom_Above_Grade
# Bedroom_Above_Grade
# Rooms_Above_Grade
# Fireplaces
# Garage_Built_Year
# Garage_Area
# Pool_Area
# Miscellaneous_Value
# Year_Sold
# Sale_Price

# %%
# Outliers Treatment
for col in contvar:
    if col!='Sale_Price':
        Q1=np.percentile(fulldf[col],25)
        Q3=np.percentile(fulldf[col],75)
        IQR=Q3-Q1
        LowerBound=Q1-1.5*IQR
        UpperBound=Q3+1.5*IQR
        UpperBound
        fulldf[col]=np.where(fulldf[col]<LowerBound,LowerBound,fulldf[col])
        fulldf[col]=np.where(fulldf[col]>UpperBound,UpperBound,fulldf[col])

# %%
sns.boxplot(y=df['Garage_Area'])
# Out:
# <AxesSubplot:ylabel='Garage_Area'>

# %%
sns.boxplot(y=fulldf['Garage_Area'])
# Out:
# <AxesSubplot:ylabel='Garage_Area'>

# %%
# Road Type
fulldf['Road_Type'].dtypes
fulldf['Road_Type'].value_counts()
sns.countplot(x=fulldf['Road_Type'])
# Out:
# <AxesSubplot:xlabel='Road_Type', ylabel='count'>

# %%
fulldf.groupby('Road_Type')['Sale_Price'].mean()
# Out:
# Road_Type
# Gravel    130190.500000
# Paved     181153.684102
# Name: Sale_Price, dtype: float64

# %%
# Property_Shape
fulldf['Property_Shape'].value_counts()
property=fulldf.groupby('Property_Shape')['Sale_Price'].mean()
property
# Out:
# Property_Shape
# IR1    206101.665289
# IR2    239833.365854
# IR3    216036.500000
# Reg    164773.492424
# Name: Sale_Price, dtype: float64

# %%
plt.pie(property.values,labels=property.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x15eb2066520>,
#   <matplotlib.patches.Wedge at 0x15eb2066a00>,
#   <matplotlib.patches.Wedge at 0x15eb2066ee0>,
#   <matplotlib.patches.Wedge at 0x15eb2073400>],
#  [Text(0.7795433735001683, 0.7760877069197638, 'IR1'),
#   Text(-0.866365792531044, 0.6777981362707161, 'IR2'),
#   Text(-0.5296790194531479, -0.9640747566196057, 'IR3'),
#   Text(0.8913306412564578, -0.6446159228233135, 'Reg')])

# %%
# Garage_Area
fulldf['Garage_Area'].dtypes
# Out:
# dtype('float64')

# %%
sns.histplot(fulldf['Garage_Area'])
# Out:
# <AxesSubplot:xlabel='Garage_Area', ylabel='Count'>

# %%
# Garage
fulldf['Garage'].value_counts()
sns.scatterplot(x=fulldf['Garage_Area'],y=fulldf['Sale_Price'])
# Out:
# <AxesSubplot:xlabel='Garage_Area', ylabel='Sale_Price'>

# %%
fulldf['Garage_Area'].max()
# Out:
# 1024.026709975

# %%
sns.scatterplot(x=fulldf['Garage_Area'],y=fulldf['Sale_Price'],hue=fulldf['Garage'])
# Out:
# <AxesSubplot:xlabel='Garage_Area', ylabel='Sale_Price'>

# %%
sns.histplot(fulldf['Garage_Area'],kde=True)
# Out:
# <AxesSubplot:xlabel='Garage_Area', ylabel='Count'>

# %% [markdown]
# # Bivariate Analysis
# # continuous Indep var. vs continuous dep var

# %%
corrdf=fulldf.corr()
corrdf
# Out:
#                            House_Condition  Construction_Year  Remodel_Year  \
# House_Condition                   1.000000          -0.399653      0.038757
# Construction_Year                -0.399653           1.000000      0.594969
# Remodel_Year                      0.038757           0.594969      1.000000
# BsmtFinSF1                       -0.045718           0.253017      0.127007
# Total_Basement_Area              -0.191959           0.410521      0.302038
# First_Floor_Area                 -0.156679           0.288461      0.246918
# Second_Floor_Area                 0.007627           0.011376      0.139562
# LowQualFinSF                           NaN                NaN           NaN
# Underground_Full_Bathroom        -0.052264           0.187782      0.120547
# Full_Bathroom_Above_Grade        -0.225534           0.469853      0.438667
# Bedroom_Above_Grade               0.005243          -0.055084     -0.034897
# Rooms_Above_Grade                -0.081303           0.106316      0.196536
# Fireplaces                       -0.037068           0.148045      0.111320
# Garage_Built_Year                -0.334266           0.779114      0.616595
# Garage_Area                      -0.017948           0.022637      0.009010
# Pool_Area                              NaN                NaN           NaN
# Miscellaneous_Value                    NaN                NaN           NaN
# Year_Sold                         0.046120          -0.013273      0.035846
# Sale_Price                       -0.106139           0.524151      0.507015
#
#                            BsmtFinSF1  Total_Basement_Area  First_Floor_Area  \
# House_Condition             -0.045718            -0.191959         -0.156679
# Construction_Year            0.253017             0.410521          0.288461
# Remodel_Year                 0.127007             0.302038          0.246918
# BsmtFinSF1                   1.000000             0.467215          0.395347
# Total_Basement_Area          0.467215             1.000000          0.807059
# First_Floor_Area             0.395347             0.807059          1.000000
# Second_Floor_Area           -0.157207            -0.205889         -0.226931
# LowQualFinSF                      NaN                  NaN               NaN
# Underground_Full_Bathroom    0.662899             0.303995          0.237080
# Full_Bathroom_Above_Grade    0.053543             0.332059          0.383804
# Bedroom_Above_Grade         -0.111380             0.048827          0.128001
# Rooms_Above_Grade            0.017557             0.271134          0.401364
# Fireplaces                   0.246820             0.330437          0.406630
# Garage_Built_Year            0.147448             0.320615          0.228015
# Garage_Area                  0.018886             0.019304         -0.008803
# Pool_Area                         NaN                  NaN               NaN
# Miscellaneous_Value               NaN                  NaN               NaN
# Year_Sold                    0.013887            -0.018578         -0.013570
# Sale_Price                   0.400715             0.637244          0.620889
#
#                            Second_Floor_Area  LowQualFinSF  \
# House_Condition                     0.007627           NaN
# Construction_Year                   0.011376           NaN
# Remodel_Year                        0.139562           NaN
# BsmtFinSF1                         -0.157207           NaN
# Total_Basement_Area                -0.205889           NaN
# First_Floor_Area                   -0.226931           NaN
# Second_Floor_Area                   1.000000           NaN
# LowQualFinSF                             NaN           NaN
# Underground_Full_Bathroom          -0.169621           NaN
# Full_Bathroom_Above_Grade           0.420557           NaN
# Bedroom_Above_Grade                 0.514766           NaN
# Rooms_Above_Grade                   0.610930           NaN
# Fireplaces                          0.194312           NaN
# Garage_Built_Year                   0.068117           NaN
# Garage_Area                        -0.038017           NaN
# Pool_Area                                NaN           NaN
# Miscellaneous_Value                      NaN           NaN
# Year_Sold                          -0.028392           NaN
# Sale_Price                          0.316405           NaN
#
#                            Underground_Full_Bathroom  \
# House_Condition                            -0.052264
# Construction_Year                           0.187782
# Remodel_Year                                0.120547
# BsmtFinSF1                                  0.662899
# Total_Basement_Area                         0.303995
# First_Floor_Area                            0.237080
# Second_Floor_Area                          -0.169621
# LowQualFinSF                                     NaN
# Underground_Full_Bathroom                   1.000000
# Full_Bathroom_Above_Grade                  -0.065699
# Bedroom_Above_Grade                        -0.151941
# Rooms_Above_Grade                          -0.055717
# Fireplaces                                  0.138060
# Garage_Built_Year                           0.120055
# Garage_Area                                 0.019661
# Pool_Area                                        NaN
# Miscellaneous_Value                              NaN
# Year_Sold                                   0.066581
# Sale_Price                                  0.228244
#
#                            Full_Bathroom_Above_Grade  Bedroom_Above_Grade  \
# House_Condition                            -0.225534             0.005243
# Construction_Year                           0.469853            -0.055084
# Remodel_Year                                0.438667            -0.034897
# BsmtFinSF1                                  0.053543            -0.111380
# Total_Basement_Area                         0.332059             0.048827
# First_Floor_Area                            0.383804             0.128001
# Second_Floor_Area                           0.420557             0.514766
# LowQualFinSF                                     NaN                  NaN
# Underground_Full_Bathroom                  -0.065699            -0.151941
# Full_Bathroom_Above_Grade                   1.000000             0.366927
# Bedroom_Above_Grade                         0.366927             1.000000
# Rooms_Above_Grade                           0.556466             0.675509
# Fireplaces                                  0.244195             0.124943
# Garage_Built_Year                           0.466859            -0.058349
# Garage_Area                                -0.033656            -0.035137
# Pool_Area                                        NaN                  NaN
# Miscellaneous_Value                              NaN                  NaN
# Year_Sold                                  -0.019578            -0.033918
# Sale_Price                                  0.560604             0.185810
#
#                            Rooms_Above_Grade  Fireplaces  Garage_Built_Year  \
# House_Condition                    -0.081303   -0.037068          -0.334266
# Construction_Year                   0.106316    0.148045           0.779114
# Remodel_Year                        0.196536    0.111320           0.616595
# BsmtFinSF1                          0.017557    0.246820           0.147448
# Total_Basement_Area                 0.271134    0.330437           0.320615
# First_Floor_Area                    0.401364    0.406630           0.228015
# Second_Floor_Area                   0.610930    0.194312           0.068117
# LowQualFinSF                             NaN         NaN                NaN
# Underground_Full_Bathroom          -0.055717    0.138060           0.120055
# Full_Bathroom_Above_Grade           0.556466    0.244195           0.466859
# Bedroom_Above_Grade                 0.675509    0.124943          -0.058349
# Rooms_Above_Grade                   1.000000    0.329837           0.140915
# Fireplaces                          0.329837    1.000000           0.042847
# Garage_Built_Year                   0.140915    0.042847           1.000000
# Garage_Area                        -0.039090    0.007432          -0.002167
# Pool_Area                                NaN         NaN                NaN
# Miscellaneous_Value                      NaN         NaN                NaN
# Year_Sold                          -0.040409   -0.025004          -0.000837
# Sale_Price                          0.536027    0.468600           0.466760
#
#                            Garage_Area  Pool_Area  Miscellaneous_Value  \
# House_Condition              -0.017948        NaN                  NaN
# Construction_Year             0.022637        NaN                  NaN
# Remodel_Year                  0.009010        NaN                  NaN
# BsmtFinSF1                    0.018886        NaN                  NaN
# Total_Basement_Area           0.019304        NaN                  NaN
# First_Floor_Area             -0.008803        NaN                  NaN
# Second_Floor_Area            -0.038017        NaN                  NaN
# LowQualFinSF                       NaN        NaN                  NaN
# Underground_Full_Bathroom     0.019661        NaN                  NaN
# Full_Bathroom_Above_Grade    -0.033656        NaN                  NaN
# Bedroom_Above_Grade          -0.035137        NaN                  NaN
# Rooms_Above_Grade            -0.039090        NaN                  NaN
# Fireplaces                    0.007432        NaN                  NaN
# Garage_Built_Year            -0.002167        NaN                  NaN
# Garage_Area                   1.000000        NaN                  NaN
# Pool_Area                          NaN        NaN                  NaN
# Miscellaneous_Value                NaN        NaN                  NaN
# Year_Sold                     0.008914        NaN                  NaN
# Sale_Price                    0.009887        NaN                  NaN
#
#                            Year_Sold  Sale_Price
# House_Condition             0.046120   -0.106139
# Construction_Year          -0.013273    0.524151
# Remodel_Year                0.035846    0.507015
# BsmtFinSF1                  0.013887    0.400715
# Total_Basement_Area        -0.018578    0.637244
# First_Floor_Area           -0.013570    0.620889
# Second_Floor_Area          -0.028392    0.316405
# LowQualFinSF                     NaN         NaN
# Underground_Full_Bathroom   0.066581    0.228244
# Full_Bathroom_Above_Grade  -0.019578    0.560604
# Bedroom_Above_Grade        -0.033918    0.185810
# Rooms_Above_Grade          -0.040409    0.536027
# Fireplaces                 -0.025004    0.468600
# Garage_Built_Year          -0.000837    0.466760
# Garage_Area                 0.008914    0.009887
# Pool_Area                        NaN         NaN
# Miscellaneous_Value              NaN         NaN
# Year_Sold                   1.000000   -0.028884
# Sale_Price                 -0.028884    1.000000

# %%
fulldf['Pool_Area'].head()
fulldf['Miscellaneous_Value'].value_counts()
fulldf['Pool_Area'].value_counts()
fulldf['LowQualFinSF'].value_counts()
# Out:
# 0.0    1459
# Name: LowQualFinSF, dtype: int64

# %%
corrdf=fulldf.drop(['Pool_Area','Miscellaneous_Value','LowQualFinSF'],axis=1).corr()
corrdf
# Out:
#                            House_Condition  Construction_Year  Remodel_Year  \
# House_Condition                   1.000000          -0.399653      0.038757
# Construction_Year                -0.399653           1.000000      0.594969
# Remodel_Year                      0.038757           0.594969      1.000000
# BsmtFinSF1                       -0.045718           0.253017      0.127007
# Total_Basement_Area              -0.191959           0.410521      0.302038
# First_Floor_Area                 -0.156679           0.288461      0.246918
# Second_Floor_Area                 0.007627           0.011376      0.139562
# Underground_Full_Bathroom        -0.052264           0.187782      0.120547
# Full_Bathroom_Above_Grade        -0.225534           0.469853      0.438667
# Bedroom_Above_Grade               0.005243          -0.055084     -0.034897
# Rooms_Above_Grade                -0.081303           0.106316      0.196536
# Fireplaces                       -0.037068           0.148045      0.111320
# Garage_Built_Year                -0.334266           0.779114      0.616595
# Garage_Area                      -0.017948           0.022637      0.009010
# Year_Sold                         0.046120          -0.013273      0.035846
# Sale_Price                       -0.106139           0.524151      0.507015
#
#                            BsmtFinSF1  Total_Basement_Area  First_Floor_Area  \
# House_Condition             -0.045718            -0.191959         -0.156679
# Construction_Year            0.253017             0.410521          0.288461
# Remodel_Year                 0.127007             0.302038          0.246918
# BsmtFinSF1                   1.000000             0.467215          0.395347
# Total_Basement_Area          0.467215             1.000000          0.807059
# First_Floor_Area             0.395347             0.807059          1.000000
# Second_Floor_Area           -0.157207            -0.205889         -0.226931
# Underground_Full_Bathroom    0.662899             0.303995          0.237080
# Full_Bathroom_Above_Grade    0.053543             0.332059          0.383804
# Bedroom_Above_Grade         -0.111380             0.048827          0.128001
# Rooms_Above_Grade            0.017557             0.271134          0.401364
# Fireplaces                   0.246820             0.330437          0.406630
# Garage_Built_Year            0.147448             0.320615          0.228015
# Garage_Area                  0.018886             0.019304         -0.008803
# Year_Sold                    0.013887            -0.018578         -0.013570
# Sale_Price                   0.400715             0.637244          0.620889
#
#                            Second_Floor_Area  Underground_Full_Bathroom  \
# House_Condition                     0.007627                  -0.052264
# Construction_Year                   0.011376                   0.187782
# Remodel_Year                        0.139562                   0.120547
# BsmtFinSF1                         -0.157207                   0.662899
# Total_Basement_Area                -0.205889                   0.303995
# First_Floor_Area                   -0.226931                   0.237080
# Second_Floor_Area                   1.000000                  -0.169621
# Underground_Full_Bathroom          -0.169621                   1.000000
# Full_Bathroom_Above_Grade           0.420557                  -0.065699
# Bedroom_Above_Grade                 0.514766                  -0.151941
# Rooms_Above_Grade                   0.610930                  -0.055717
# Fireplaces                          0.194312                   0.138060
# Garage_Built_Year                   0.068117                   0.120055
# Garage_Area                        -0.038017                   0.019661
# Year_Sold                          -0.028392                   0.066581
# Sale_Price                          0.316405                   0.228244
#
#                            Full_Bathroom_Above_Grade  Bedroom_Above_Grade  \
# House_Condition                            -0.225534             0.005243
# Construction_Year                           0.469853            -0.055084
# Remodel_Year                                0.438667            -0.034897
# BsmtFinSF1                                  0.053543            -0.111380
# Total_Basement_Area                         0.332059             0.048827
# First_Floor_Area                            0.383804             0.128001
# Second_Floor_Area                           0.420557             0.514766
# Underground_Full_Bathroom                  -0.065699            -0.151941
# Full_Bathroom_Above_Grade                   1.000000             0.366927
# Bedroom_Above_Grade                         0.366927             1.000000
# Rooms_Above_Grade                           0.556466             0.675509
# Fireplaces                                  0.244195             0.124943
# Garage_Built_Year                           0.466859            -0.058349
# Garage_Area                                -0.033656            -0.035137
# Year_Sold                                  -0.019578            -0.033918
# Sale_Price                                  0.560604             0.185810
#
#                            Rooms_Above_Grade  Fireplaces  Garage_Built_Year  \
# House_Condition                    -0.081303   -0.037068          -0.334266
# Construction_Year                   0.106316    0.148045           0.779114
# Remodel_Year                        0.196536    0.111320           0.616595
# BsmtFinSF1                          0.017557    0.246820           0.147448
# Total_Basement_Area                 0.271134    0.330437           0.320615
# First_Floor_Area                    0.401364    0.406630           0.228015
# Second_Floor_Area                   0.610930    0.194312           0.068117
# Underground_Full_Bathroom          -0.055717    0.138060           0.120055
# Full_Bathroom_Above_Grade           0.556466    0.244195           0.466859
# Bedroom_Above_Grade                 0.675509    0.124943          -0.058349
# Rooms_Above_Grade                   1.000000    0.329837           0.140915
# Fireplaces                          0.329837    1.000000           0.042847
# Garage_Built_Year                   0.140915    0.042847           1.000000
# Garage_Area                        -0.039090    0.007432          -0.002167
# Year_Sold                          -0.040409   -0.025004          -0.000837
# Sale_Price                          0.536027    0.468600           0.466760
#
#                            Garage_Area  Year_Sold  Sale_Price
# House_Condition              -0.017948   0.046120   -0.106139
# Construction_Year             0.022637  -0.013273    0.524151
# Remodel_Year                  0.009010   0.035846    0.507015
# BsmtFinSF1                    0.018886   0.013887    0.400715
# Total_Basement_Area           0.019304  -0.018578    0.637244
# First_Floor_Area             -0.008803  -0.013570    0.620889
# Second_Floor_Area            -0.038017  -0.028392    0.316405
# Underground_Full_Bathroom     0.019661   0.066581    0.228244
# Full_Bathroom_Above_Grade    -0.033656  -0.019578    0.560604
# Bedroom_Above_Grade          -0.035137  -0.033918    0.185810
# Rooms_Above_Grade            -0.039090  -0.040409    0.536027
# Fireplaces                    0.007432  -0.025004    0.468600
# Garage_Built_Year            -0.002167  -0.000837    0.466760
# Garage_Area                   1.000000   0.008914    0.009887
# Year_Sold                     0.008914   1.000000   -0.028884
# Sale_Price                    0.009887  -0.028884    1.000000

# %%
plt.figure(figsize=(15,15))
sns.heatmap(corrdf,annot=True,cmap='rainbow')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Indep categorical var vs dep. continuous var

# %%
catVar=fulldf.columns[fulldf.dtypes=='O']
catVar
# Out:
# Index(['Road_Type', 'Property_Shape', 'House_Type', 'Air_Conditioning',
#        'Kitchen_Quality', 'Garage'],
#       dtype='object')

# %%
for i in catVar:
    print(i)
    plt.figure()
    sns.boxplot(y=fulldf['Sale_Price'],x=fulldf[i])
# Out:
# Road_Type
# Property_Shape
# House_Type
# Air_Conditioning
# Kitchen_Quality
# Garage

# %%
df.head()
# Out:
#    Id Road_Type Property_Shape House_Type  House_Condition  Construction_Year  \
# 0   1     Paved            Reg       1Fam                5               2003
# 1   2     Paved            Reg       1Fam                8               1976
# 2   3     Paved            IR1       1Fam                5               2001
# 3   4     Paved            IR1       1Fam                5               1915
# 4   5     Paved            IR1       1Fam                5               2000
#
#    Remodel_Year  BsmtFinSF1  Total_Basement_Area Air_Conditioning  ...  \
# 0          2003         706                  856                Y  ...
# 1          1976         978                 1262                Y  ...
# 2          2002         486                  920                Y  ...
# 3          1970         216                  756                Y  ...
# 4          2000         655                 1145                Y  ...
#
#    Kitchen_Quality  Rooms_Above_Grade  Fireplaces  Garage  Garage_Built_Year  \
# 0               Gd                  8           0  Attchd             2003.0
# 1               TA                  6           1  Attchd             1976.0
# 2               Gd                  6           1  Attchd             2001.0
# 3               Gd                  7           1  Detchd             1998.0
# 4               Gd                  9           1  Attchd             2000.0
#
#    Garage_Area Pool_Area  Miscellaneous_Value  Year_Sold Sale_Price
# 0  1085.793744         0                    0       2008     208500
# 1   196.316304         0                    0       2007     181500
# 2   218.068403         0                    0       2008     223500
# 3   696.996439         0                    0       2006     140000
# 4   568.859882         0                    0       2008     250000
#
# [5 rows x 26 columns]

# %%
df['Pool_Area'].value_counts()
# Out:
# 0      1452
# 512       1
# 648       1
# 576       1
# 555       1
# 480       1
# 519       1
# 738       1
# Name: Pool_Area, dtype: int64

# %%
df['Pool_Status']=np.where(df['Pool_Area']==0,'NoPool','YesPool')

# %%
sns.boxplot(y=df['Sale_Price'],x=df['Pool_Status'])
# Out:
# <AxesSubplot:xlabel='Pool_Status', ylabel='Sale_Price'>

# %%
df['Miscellaneous_Value'].value_counts()
# Out:
# 0        1407
# 400        11
# 500         8
# 700         5
# 450         4
# 600         4
# 2000        4
# 1200        2
# 480         2
# 15500       1
# 800         1
# 350         1
# 3500        1
# 1300        1
# 54          1
# 620         1
# 560         1
# 1400        1
# 8300        1
# 1150        1
# 2500        1
# Name: Miscellaneous_Value, dtype: int64

# %%
df['Misc_Val']=np.where(df['Miscellaneous_Value']==0,'NoMiscItem','YesMiscItem')

# %%
sns.boxplot(y=df['Sale_Price'],x=df['Misc_Val'])
# Out:
# <AxesSubplot:xlabel='Misc_Val', ylabel='Sale_Price'>

# %%
df['LowQualFinSF'].value_counts().sample()
# Out:
# 392    1
# Name: LowQualFinSF, dtype: int64

# %%
df['LowQual']=np.where(df['LowQualFinSF']==0,'NoLowQual','YesQual')

# %%
sns.boxplot(y=df['Sale_Price'],x=df['LowQual'])
# Out:
# <AxesSubplot:xlabel='LowQual', ylabel='Sale_Price'>

# %%
contvar
df[['Total_Basement_Area','Fireplaces','Garage_Area']].head()
# Out:
#    Total_Basement_Area  Fireplaces  Garage_Area
# 0                  856           0  1085.793744
# 1                 1262           1   196.316304
# 2                  920           1   218.068403
# 3                  756           1   696.996439
# 4                 1145           1   568.859882

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler().fit(df[contvar])

# %%
dfcontscaler=scaler.transform(df[contvar])

# %%
dfcontscalerdf=pd.DataFrame(dfcontscaler,columns=contvar)
dfcontscalerdf.head()
# Out:
#    House_Condition  Construction_Year  Remodel_Year  BsmtFinSF1  \
# 0            0.500           0.949275      0.883333    0.125089
# 1            0.875           0.753623      0.433333    0.173281
# 2            0.500           0.934783      0.866667    0.086109
# 3            0.500           0.311594      0.333333    0.038271
# 4            0.500           0.927536      0.833333    0.116052
#
#    Total_Basement_Area  First_Floor_Area  Second_Floor_Area  LowQualFinSF  \
# 0             0.140098          0.119780           0.413559           0.0
# 1             0.206547          0.212942           0.000000           0.0
# 2             0.150573          0.134465           0.419370           0.0
# 3             0.123732          0.143873           0.366102           0.0
# 4             0.187398          0.186095           0.509927           0.0
#
#    Underground_Full_Bathroom  Full_Bathroom_Above_Grade  Bedroom_Above_Grade  \
# 0                   0.333333                   0.666667                0.375
# 1                   0.000000                   0.666667                0.375
# 2                   0.333333                   0.666667                0.375
# 3                   0.333333                   0.333333                0.375
# 4                   0.333333                   0.666667                0.500
#
#    Rooms_Above_Grade  Fireplaces  Garage_Built_Year  Garage_Area  Pool_Area  \
# 0           0.500000    0.000000           0.936364     0.951683        0.0
# 1           0.333333    0.333333           0.690909     0.255068        0.0
# 2           0.333333    0.333333           0.918182     0.272104        0.0
# 3           0.416667    0.333333           0.890909     0.647187        0.0
# 4           0.583333    0.333333           0.909091     0.546834        0.0
#
#    Miscellaneous_Value  Year_Sold  Sale_Price
# 0                  0.0       0.50    0.241078
# 1                  0.0       0.25    0.203583
# 2                  0.0       0.50    0.261908
# 3                  0.0       0.00    0.145952
# 4                  0.0       0.50    0.298709
